# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import sklearn
import sklearn.preprocessing
import sklearn.model_selection
import datetime

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)

# %%
input_tensor = tf.keras.Input(shape=(68,68,3))

model_res = tf.keras.applications.ResNet50V2(include_top = True, weights = 'imagenet', input_tensor = input_tensor)

# for layer in model_res.layers[:143]:
#     layer.trainable = False

model = tf.keras.models.Sequential()
model.add(model_res)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(12, activation = 'softmax'))


model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-2, momentum=0.9, decay = 0.01),metrics=['accuracy'])

# history=model.fit(train_dataloader, validation_data=test_dataloader, epochs= 50, callbacks = [check_point, rlrop, csv_logger])
model.summary()
# model.save(path_model)
# Out:
# ...
# 102883328/102869336 [==============================] - 39s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50v2 (Functional)     (None, 1000)              25613800
#
#  flatten_1 (Flatten)         (None, 1000)              0
#
#  dense_1 (Dense)             (None, 12)                12012
#
# ...
# Total params: 25,625,812
# Trainable params: 25,580,372
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
model.layers[0].summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 68, 68, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 74, 74, 3)    0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 34, 34, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 36, 36, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 17, 17, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 17, 17, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 17, 17, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 17, 17, 64)   4096        ['conv2_block1_preact_relu[0][0]'
# ...
