# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import sklearn
import sklearn.preprocessing
import sklearn.model_selection
import datetime

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)

# %%
class DataLoader(tf.keras.utils.Sequence):
    #def __init__(self, df, model = None, one_hot_encoder, learning_rate_schedule = None, batch_size, input_size = (68,68,3), shuffle = True):
    def __init__(self, df, one_hot_encoder, batch_size, model = None, input_size = (68,68,3), shuffle = True):
        self.df = df
        self.dmsomean = np.load('F:\Programming\DTU\Human MCF7\Segmented\Inspection\ClassMean\DMSO.npy')
        self.batch_size = batch_size
        self.input_size = input_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
        self.n_classes = self.df['moa'].nunique()
        
        self.one_hot_encoder = one_hot_encoder
        
        #self.learning_rate_schedule = iter(learning_rate_schedule)
        
        self.on_epoch_end()
        
        
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
        
        # lr = self.get_next_learning_rate()
        # if lr:
        #     tf.keras.backend.set_value(model.optimizer.learning_rate, lr)
        #     print(f"Learning rate adjusted to: {lr}")
            
    # def get_next_learning_rate(self):
    #     try:
    #         lr = next(self.learning_rate_schedule)
    #     except StopIteration:
    #         lr = None
    #     return lr

    def __get_img(self, path):
        image_arr = np.load(path)
        image_arr = image_arr/255
        image_arr -= self.dmsomean #Normalize by dmso

        image_arr = tf.image.resize(image_arr, (self.input_size[0], self.input_size[1]))
        return image_arr
    
    def __get_label(self, moa):
        #print(moa)
        label = self.one_hot_encoder.transform(moa.to_numpy().reshape(-1, 1))
        return label
    
    def __get_batch(self, batch):

        img_batch = batch['path'].apply(self.__get_img)
        img_batch = np.array([img for img in img_batch])
        img_batch = tf.keras.applications.resnet50.preprocess_input(img_batch)
        

        #label_batch = batch['moa'].apply(self.__get_label)
        label_batch = self.one_hot_encoder.transform(batch.moa.to_numpy().reshape(-1, 1))
        
        return img_batch, label_batch
    
    def __getitem__(self, index):
        batch = self.df[index * self.batch_size:(index+1)*self.batch_size]
        X, Y = self.__get_batch(batch)
        return X, Y
        
    def __len__(self):
        return self.n // self.batch_size

# %%
path = 'Data_paths.csv'
df = pd.read_csv(path)
df = df[df.moa != 'DMSO']

# %%
moa_one_hot_encoder = sklearn.preprocessing.OneHotEncoder(sparse=False)
moa_one_hot_encoder.fit(df['moa'].to_numpy().reshape(-1, 1))
# Out:
# OneHotEncoder(sparse=False)

# %%
indices = np.arange(len(df))
X_train, X_test, y_train, y_test, idx_train, idx_test = sklearn.model_selection.train_test_split(df['path'], df['moa'], indices, test_size = 0.5, random_state=0, shuffle = True, stratify=df['moa'])

df_train = df.loc[idx_train]
df_test = df.loc[idx_test]

# %%
import init_models
for i in range(4):
    model_id = datetime.datetime.now().strftime("%Y.%m.%d_%H.%M.%S")
    base_path = 'train_results'
    path_checkpoint = os.path.join(base_path, model_id+'_checkpoint.h5')
    path_model = os.path.join(base_path, model_id+'_model.h5')  
    path_log = os.path.join(base_path, model_id+'_log.csv')  
    
    model = init_models.init_model(i)

    #train_dataloader = DataLoader(df = df_train, model = model, one_hot_encoder = moa_one_hot_encoder, learning_rate_schedule, batch_size=32, input_size=(68,68,3))
    train_dataloader = DataLoader(df = df_train, model = model, one_hot_encoder = moa_one_hot_encoder, batch_size=32, input_size=(68,68,3))
    test_dataloader = DataLoader(df = df_test, one_hot_encoder = moa_one_hot_encoder, batch_size = 32, input_size=(68,68,3))


    rlrop = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor = 0.1, patience = 5, min_lr=1e-6)
    check_point = tf.keras.callbacks.ModelCheckpoint(filepath=path_checkpoint , monitor = "val_acc", mode = "max", save_best_only=True)
    csv_logger = tf.keras.callbacks.CSVLogger(path_log, append = True, separator=',')
    model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-2, momentum=0.9, decay = 0.01),metrics=['accuracy'])

    history=model.fit(train_dataloader, validation_data=test_dataloader, epochs= 50, callbacks = [check_point, rlrop, csv_logger])
    model.summary()
    model.save(path_model)
# Out:
# Epoch 1/50
# 2901/2901 [==============================] - ETA: 0s - loss: 2.4538 - accuracy: 0.4406WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 1402s 480ms/step - loss: 2.4538 - accuracy: 0.4406 - val_loss: 4160.2280 - val_accuracy: 0.0506 - lr: 0.0100
# Epoch 2/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6148 - accuracy: 0.4918WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 1250s 431ms/step - loss: 1.6148 - accuracy: 0.4918 - val_loss: 7506.9360 - val_accuracy: 0.0506 - lr: 0.0100
# Epoch 3/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.4515 - accuracy: 0.5349WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 409s 141ms/step - loss: 1.4515 - accuracy: 0.5349 - val_loss: 15594.3828 - val_accuracy: 0.0506 - lr: 0.0100
# Epoch 4/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.3456 - accuracy: 0.5604WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 407s 140ms/step - loss: 1.3456 - accuracy: 0.5604 - val_loss: 2.5455 - val_accuracy: 0.4278 - lr: 0.0100
# Epoch 5/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.2527 - accuracy: 0.5842WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 411s 142ms/step - loss: 1.2527 - accuracy: 0.5842 - val_loss: 193.1004 - val_accuracy: 0.3817 - lr: 0.0100
# Epoch 6/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.1733 - accuracy: 0.6082WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 407s 140ms/step - loss: 1.1733 - accuracy: 0.6082 - val_loss: 46.6554 - val_accuracy: 0.3690 - lr: 0.0100
# Epoch 7/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.1038 - accuracy: 0.6304WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 413s 142ms/step - loss: 1.1038 - accuracy: 0.6304 - val_loss: 11.9760 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 8/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.0455 - accuracy: 0.6504WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 1.0455 - accuracy: 0.6504 - val_loss: 12.4835 - val_accuracy: 0.4367 - lr: 0.0100
# Epoch 9/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.9982 - accuracy: 0.6660WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 410s 141ms/step - loss: 0.9982 - accuracy: 0.6660 - val_loss: 14.7360 - val_accuracy: 0.4088 - lr: 0.0100
# Epoch 10/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.9196 - accuracy: 0.6917WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 0.9196 - accuracy: 0.6917 - val_loss: 0.9632 - val_accuracy: 0.6767 - lr: 1.0000e-03
# Epoch 11/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.9055 - accuracy: 0.6951WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 410s 141ms/step - loss: 0.9055 - accuracy: 0.6951 - val_loss: 1.0929 - val_accuracy: 0.6432 - lr: 1.0000e-03
# Epoch 12/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8971 - accuracy: 0.6982WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 0.8971 - accuracy: 0.6982 - val_loss: 1.2699 - val_accuracy: 0.5631 - lr: 1.0000e-03
# Epoch 13/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8942 - accuracy: 0.6990WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 411s 142ms/step - loss: 0.8942 - accuracy: 0.6990 - val_loss: 1.6128 - val_accuracy: 0.5001 - lr: 1.0000e-03
# Epoch 14/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8832 - accuracy: 0.7035WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 0.8832 - accuracy: 0.7035 - val_loss: 1.3110 - val_accuracy: 0.5880 - lr: 1.0000e-03
# Epoch 15/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8801 - accuracy: 0.7036WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 416s 143ms/step - loss: 0.8801 - accuracy: 0.7036 - val_loss: 1.3137 - val_accuracy: 0.5639 - lr: 1.0000e-03
# Epoch 16/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8753 - accuracy: 0.7058WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 410s 142ms/step - loss: 0.8753 - accuracy: 0.7058 - val_loss: 0.9176 - val_accuracy: 0.6922 - lr: 1.0000e-04
# Epoch 17/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8728 - accuracy: 0.7071WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 414s 143ms/step - loss: 0.8728 - accuracy: 0.7071 - val_loss: 0.9350 - val_accuracy: 0.6869 - lr: 1.0000e-04
# Epoch 18/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8734 - accuracy: 0.7069WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 0.8734 - accuracy: 0.7069 - val_loss: 0.9725 - val_accuracy: 0.6762 - lr: 1.0000e-04
# Epoch 19/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8714 - accuracy: 0.7068WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 411s 142ms/step - loss: 0.8714 - accuracy: 0.7068 - val_loss: 0.9145 - val_accuracy: 0.6934 - lr: 1.0000e-04
# Epoch 20/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8720 - accuracy: 0.7069WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 140ms/step - loss: 0.8720 - accuracy: 0.7069 - val_loss: 0.9144 - val_accuracy: 0.6927 - lr: 1.0000e-04
# Epoch 21/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8712 - accuracy: 0.7077WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 411s 142ms/step - loss: 0.8712 - accuracy: 0.7077 - val_loss: 0.9245 - val_accuracy: 0.6904 - lr: 1.0000e-04
# Epoch 22/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8725 - accuracy: 0.7065WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 407s 140ms/step - loss: 0.8725 - accuracy: 0.7065 - val_loss: 0.9169 - val_accuracy: 0.6925 - lr: 1.0000e-04
# Epoch 23/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8695 - accuracy: 0.7087WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 411s 142ms/step - loss: 0.8695 - accuracy: 0.7087 - val_loss: 0.9193 - val_accuracy: 0.6914 - lr: 1.0000e-04
# Epoch 24/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8695 - accuracy: 0.7073WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 0.8695 - accuracy: 0.7073 - val_loss: 0.9301 - val_accuracy: 0.6890 - lr: 1.0000e-04
# Epoch 25/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8699 - accuracy: 0.7070WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8699 - accuracy: 0.7070 - val_loss: 0.9229 - val_accuracy: 0.6912 - lr: 1.0000e-05
# Epoch 26/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8689 - accuracy: 0.7086WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8689 - accuracy: 0.7086 - val_loss: 0.9252 - val_accuracy: 0.6908 - lr: 1.0000e-05
# Epoch 27/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8713 - accuracy: 0.7068WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 0.8713 - accuracy: 0.7068 - val_loss: 0.9210 - val_accuracy: 0.6916 - lr: 1.0000e-05
# Epoch 28/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8690 - accuracy: 0.7076WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 409s 141ms/step - loss: 0.8690 - accuracy: 0.7076 - val_loss: 0.9225 - val_accuracy: 0.6907 - lr: 1.0000e-05
# Epoch 29/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8711 - accuracy: 0.7072WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 413s 142ms/step - loss: 0.8711 - accuracy: 0.7072 - val_loss: 0.9200 - val_accuracy: 0.6919 - lr: 1.0000e-05
# Epoch 30/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.7079WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 406s 140ms/step - loss: 0.8697 - accuracy: 0.7079 - val_loss: 0.9184 - val_accuracy: 0.6924 - lr: 1.0000e-06
# Epoch 31/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8713 - accuracy: 0.7076WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 413s 142ms/step - loss: 0.8713 - accuracy: 0.7076 - val_loss: 0.9214 - val_accuracy: 0.6915 - lr: 1.0000e-06
# Epoch 32/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8681 - accuracy: 0.7080WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 407s 140ms/step - loss: 0.8681 - accuracy: 0.7080 - val_loss: 0.9181 - val_accuracy: 0.6925 - lr: 1.0000e-06
# Epoch 33/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8691 - accuracy: 0.7070WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 0.8691 - accuracy: 0.7070 - val_loss: 0.9171 - val_accuracy: 0.6929 - lr: 1.0000e-06
# Epoch 34/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8685 - accuracy: 0.7086WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 409s 141ms/step - loss: 0.8685 - accuracy: 0.7086 - val_loss: 0.9194 - val_accuracy: 0.6922 - lr: 1.0000e-06
# Epoch 35/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8682 - accuracy: 0.7083WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 0.8682 - accuracy: 0.7083 - val_loss: 0.9174 - val_accuracy: 0.6925 - lr: 1.0000e-06
# Epoch 36/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8695 - accuracy: 0.7076WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 409s 141ms/step - loss: 0.8695 - accuracy: 0.7076 - val_loss: 0.9172 - val_accuracy: 0.6927 - lr: 1.0000e-06
# Epoch 37/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8700 - accuracy: 0.7075WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8700 - accuracy: 0.7075 - val_loss: 0.9181 - val_accuracy: 0.6922 - lr: 1.0000e-06
# Epoch 38/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8698 - accuracy: 0.7080WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 410s 141ms/step - loss: 0.8698 - accuracy: 0.7080 - val_loss: 0.9235 - val_accuracy: 0.6911 - lr: 1.0000e-06
# Epoch 39/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8688 - accuracy: 0.7081WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8688 - accuracy: 0.7081 - val_loss: 0.9169 - val_accuracy: 0.6931 - lr: 1.0000e-06
# Epoch 40/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8682 - accuracy: 0.7088WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 408s 141ms/step - loss: 0.8682 - accuracy: 0.7088 - val_loss: 0.9176 - val_accuracy: 0.6923 - lr: 1.0000e-06
# Epoch 41/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8702 - accuracy: 0.7073WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 411s 142ms/step - loss: 0.8702 - accuracy: 0.7073 - val_loss: 0.9199 - val_accuracy: 0.6920 - lr: 1.0000e-06
# Epoch 42/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8701 - accuracy: 0.7069WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8701 - accuracy: 0.7069 - val_loss: 0.9200 - val_accuracy: 0.6918 - lr: 1.0000e-06
# Epoch 43/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8684 - accuracy: 0.7081WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 0.8684 - accuracy: 0.7081 - val_loss: 0.9177 - val_accuracy: 0.6925 - lr: 1.0000e-06
# Epoch 44/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.7076WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8697 - accuracy: 0.7076 - val_loss: 0.9209 - val_accuracy: 0.6916 - lr: 1.0000e-06
# Epoch 45/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8684 - accuracy: 0.7088WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 416s 143ms/step - loss: 0.8684 - accuracy: 0.7088 - val_loss: 0.9205 - val_accuracy: 0.6920 - lr: 1.0000e-06
# Epoch 46/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8696 - accuracy: 0.7080WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 410s 141ms/step - loss: 0.8696 - accuracy: 0.7080 - val_loss: 0.9204 - val_accuracy: 0.6918 - lr: 1.0000e-06
# Epoch 47/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8689 - accuracy: 0.7082WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 0.8689 - accuracy: 0.7082 - val_loss: 0.9216 - val_accuracy: 0.6916 - lr: 1.0000e-06
# Epoch 48/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8700 - accuracy: 0.7068WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 409s 141ms/step - loss: 0.8700 - accuracy: 0.7068 - val_loss: 0.9204 - val_accuracy: 0.6919 - lr: 1.0000e-06
# Epoch 49/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8676 - accuracy: 0.7085WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 414s 143ms/step - loss: 0.8676 - accuracy: 0.7085 - val_loss: 0.9164 - val_accuracy: 0.6927 - lr: 1.0000e-06
# Epoch 50/50
# 2901/2901 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.7070WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 410s 141ms/step - loss: 0.8697 - accuracy: 0.7070 - val_loss: 0.9206 - val_accuracy: 0.6918 - lr: 1.0000e-06
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 3, 3, 2048)        23564800
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 12)                221196
#
# =================================================================
# Total params: 23,785,996
# Trainable params: 23,740,556
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.8100 - accuracy: 0.4424WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 424s 145ms/step - loss: 1.8100 - accuracy: 0.4424 - val_loss: 442.7795 - val_accuracy: 0.4314 - lr: 0.0100
# Epoch 2/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6867 - accuracy: 0.4593WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 417s 144ms/step - loss: 1.6867 - accuracy: 0.4593 - val_loss: 1373.2982 - val_accuracy: 0.4314 - lr: 0.0100
# Epoch 3/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6670 - accuracy: 0.4632WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 423s 146ms/step - loss: 1.6670 - accuracy: 0.4632 - val_loss: 1375.2808 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 4/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6568 - accuracy: 0.4653WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 416s 143ms/step - loss: 1.6568 - accuracy: 0.4653 - val_loss: 4.1639 - val_accuracy: 0.0310 - lr: 0.0100
# Epoch 5/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6500 - accuracy: 0.4679WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 418s 144ms/step - loss: 1.6500 - accuracy: 0.4679 - val_loss: 266.3237 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 6/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6484 - accuracy: 0.4670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 1.6484 - accuracy: 0.4670 - val_loss: 4.8531 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 7/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6419 - accuracy: 0.4682WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 419s 144ms/step - loss: 1.6419 - accuracy: 0.4682 - val_loss: 572.9662 - val_accuracy: 0.4314 - lr: 0.0100
# Epoch 8/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6353 - accuracy: 0.4692WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 414s 143ms/step - loss: 1.6353 - accuracy: 0.4692 - val_loss: 4.6693 - val_accuracy: 0.4314 - lr: 0.0100
# Epoch 9/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6333 - accuracy: 0.4701WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 417s 144ms/step - loss: 1.6333 - accuracy: 0.4701 - val_loss: 14.1186 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 10/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6231 - accuracy: 0.4704WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 413s 142ms/step - loss: 1.6231 - accuracy: 0.4704 - val_loss: 8.0571 - val_accuracy: 0.1542 - lr: 1.0000e-03
# Epoch 11/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6236 - accuracy: 0.4712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 420s 145ms/step - loss: 1.6236 - accuracy: 0.4712 - val_loss: 18.5812 - val_accuracy: 0.4145 - lr: 1.0000e-03
# Epoch 12/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6228 - accuracy: 0.4707WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 1.6228 - accuracy: 0.4707 - val_loss: 3.7361 - val_accuracy: 0.4304 - lr: 1.0000e-03
# Epoch 13/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6218 - accuracy: 0.4705WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 417s 144ms/step - loss: 1.6218 - accuracy: 0.4705 - val_loss: 4.1472 - val_accuracy: 0.4302 - lr: 1.0000e-03
# Epoch 14/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6212 - accuracy: 0.4703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 414s 143ms/step - loss: 1.6212 - accuracy: 0.4703 - val_loss: 15.8584 - val_accuracy: 0.4193 - lr: 1.0000e-03
# Epoch 15/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6203 - accuracy: 0.4709WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 418s 144ms/step - loss: 1.6203 - accuracy: 0.4709 - val_loss: 3.5787 - val_accuracy: 0.4307 - lr: 1.0000e-03
# Epoch 16/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6211 - accuracy: 0.4706WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 1.6211 - accuracy: 0.4706 - val_loss: 2.4972 - val_accuracy: 0.4353 - lr: 1.0000e-03
# Epoch 17/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6215 - accuracy: 0.4712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 418s 144ms/step - loss: 1.6215 - accuracy: 0.4712 - val_loss: 1.5882 - val_accuracy: 0.4767 - lr: 1.0000e-03
# Epoch 18/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6221 - accuracy: 0.4703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 1.6221 - accuracy: 0.4703 - val_loss: 1.7259 - val_accuracy: 0.4612 - lr: 1.0000e-03
# Epoch 19/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6196 - accuracy: 0.4711WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 416s 144ms/step - loss: 1.6196 - accuracy: 0.4711 - val_loss: 10.1124 - val_accuracy: 0.4313 - lr: 1.0000e-03
# Epoch 20/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6184 - accuracy: 0.4714WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 415s 143ms/step - loss: 1.6184 - accuracy: 0.4714 - val_loss: 1.9872 - val_accuracy: 0.3983 - lr: 1.0000e-03
# Epoch 21/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6198 - accuracy: 0.4714WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 420s 145ms/step - loss: 1.6198 - accuracy: 0.4714 - val_loss: 15.5943 - val_accuracy: 0.3590 - lr: 1.0000e-03
# Epoch 22/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6192 - accuracy: 0.4708WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 414s 143ms/step - loss: 1.6192 - accuracy: 0.4708 - val_loss: 20.8735 - val_accuracy: 0.4196 - lr: 1.0000e-03
# Epoch 23/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6192 - accuracy: 0.4723WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 418s 144ms/step - loss: 1.6192 - accuracy: 0.4723 - val_loss: 1.8327 - val_accuracy: 0.4374 - lr: 1.0000e-04
# Epoch 24/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6182 - accuracy: 0.4713WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 412s 142ms/step - loss: 1.6182 - accuracy: 0.4713 - val_loss: 1.9233 - val_accuracy: 0.4498 - lr: 1.0000e-04
# Epoch 25/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6193 - accuracy: 0.4712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 416s 144ms/step - loss: 1.6193 - accuracy: 0.4712 - val_loss: 1.9117 - val_accuracy: 0.4191 - lr: 1.0000e-04
# Epoch 26/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6176 - accuracy: 0.4708WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 413s 142ms/step - loss: 1.6176 - accuracy: 0.4708 - val_loss: 1.6246 - val_accuracy: 0.4713 - lr: 1.0000e-04
# Epoch 27/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6167 - accuracy: 0.4722WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 419s 144ms/step - loss: 1.6167 - accuracy: 0.4722 - val_loss: 2.2695 - val_accuracy: 0.3125 - lr: 1.0000e-04
# Epoch 28/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6191 - accuracy: 0.4714WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 416s 143ms/step - loss: 1.6191 - accuracy: 0.4714 - val_loss: 2.1989 - val_accuracy: 0.3369 - lr: 1.0000e-05
# Epoch 29/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6195 - accuracy: 0.4712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 421s 145ms/step - loss: 1.6195 - accuracy: 0.4712 - val_loss: 2.2805 - val_accuracy: 0.3085 - lr: 1.0000e-05
# Epoch 30/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6196 - accuracy: 0.4712WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 417s 144ms/step - loss: 1.6196 - accuracy: 0.4712 - val_loss: 2.1046 - val_accuracy: 0.3657 - lr: 1.0000e-05
# Epoch 31/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6164 - accuracy: 0.4719WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 418s 144ms/step - loss: 1.6164 - accuracy: 0.4719 - val_loss: 2.2104 - val_accuracy: 0.3315 - lr: 1.0000e-05
# Epoch 32/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6183 - accuracy: 0.4716WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 414s 143ms/step - loss: 1.6183 - accuracy: 0.4716 - val_loss: 2.1393 - val_accuracy: 0.3558 - lr: 1.0000e-05
# Epoch 33/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6179 - accuracy: 0.4710WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 417s 144ms/step - loss: 1.6179 - accuracy: 0.4710 - val_loss: 2.1463 - val_accuracy: 0.3523 - lr: 1.0000e-06
# Epoch 34/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6186 - accuracy: 0.4718WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2901/2901 [==============================] - 413s 142ms/step - loss: 1.6186 - accuracy: 0.4718 - val_loss: 2.1554 - val_accuracy: 0.3500 - lr: 1.0000e-06
# Epoch 35/50
# 2901/2901 [==============================] - ETA: 0s - loss: 1.6185 - accuracy: 0.4707
